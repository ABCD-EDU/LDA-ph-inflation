# %%
#Load the required libraries
import pandas as pd
import numpy as np
import seaborn as sns

#Load the data
df = pd.read_csv('data/tiktok-sorted.csv')


#View the data
df.head()
# Out:
#                                         Comment Text  Likes
# 0                                sis lugi ata farmer    266
# 1                            bat ka nagseself talk 😰    175
# 2  Kakaiba tlga mga pilitista, dati poltical scie...    134
# 3                         are you a nurse din po ba?     96
# 4      sure, buong Pilipinas ba Tig-bente ang bigas?     70

# %%
#Find the duplicates

df.duplicated().sum()
# Out:
# 2

# %%
#Find null values

df.isnull().sum()
# Out:
# Comment Text    0
# Likes           0
# dtype: int64

# %%
df['Comment Text'].unique()
# Out:
# array(['sis lugi ata farmer', 'bat ka nagseself talk 😰',
#        'Kakaiba tlga mga pilitista, dati poltical scientist kayo tas naging msrketing expert then ngayon economista na😂',
#        ...,
#        'isend konga toh sa mga leniplokers na prend ko na feeling economists 😂😂😂',
#        'Yung kakasimula palang ni bbm 😂😂😂😂. tuloy mulng yan Malay mu babagsak Ang pilipinas😂😂😂😂',
#        'if leni win government fail 😂'], dtype=object)

# %%
from wordcloud import WordCloud
from cleantext import clean
import matplotlib.pyplot as plt
import pandas as pd
import nltk


comment_words = ''
word_data = ''

for word in df['Comment Text']:
    word = str(word)
    
    tokens = word.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    comment_words += " ".join(tokens)+" "
    
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(comment_words)

# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
