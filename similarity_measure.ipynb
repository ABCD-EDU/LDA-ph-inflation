# %%
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
dataframe = pd.read_csv('./data/labelled_dataset.csv')
dataframe.head()
# Out:
#    Platform                                               Text   Topic 1  \
# 0  Facebook  nowadays every thing seem increasing governanc...  0.953512
# 1  Facebook                                      disagree high  0.055609
# 2  Facebook  wag tayong magalala naniniwala isusuprise sir ...  0.000000
# 3  Facebook  ok yang nang bansa ganyan selfish fanatic blen...  0.134108
# 4  Facebook                             samasama tayong babaon  0.041726
#
#     Topic 2   Topic 3   Topic 4   Topic 5   Topic 6  Best Topic
# 0  0.000000  0.000000  0.000000  0.000000  0.000000           1
# 1  0.055623  0.055557  0.722094  0.055557  0.055561           4
# 2  0.000000  0.000000  0.010050  0.000000  0.950684           6
# 3  0.018535  0.464663  0.018795  0.018535  0.345364           3
# 4  0.041726  0.041726  0.041727  0.285802  0.547294           6

# %%
corpus = list(dataframe["Text"])

# %%
tfidf = TfidfVectorizer()

# Construct the TF-IDF matrix
tfidf_matrix = tfidf.fit_transform(corpus)


# Generate cosine similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
row_col_names = [f"doc{i+1}" for i in range(len(corpus))]

# %%
matrix = pd.DataFrame(cosine_sim, index=row_col_names, columns=row_col_names )

# %%
matrix
# Out:
#              doc1  doc2      doc3      doc4      doc5  doc6      doc7  doc8  \
# doc1     1.000000   0.0  0.000000  0.127052  0.000000   0.0  0.000000   0.0
# doc2     0.000000   1.0  0.000000  0.000000  0.000000   0.0  0.000000   0.0
# doc3     0.000000   0.0  1.000000  0.000000  0.098216   0.0  0.034398   0.0
# doc4     0.127052   0.0  0.000000  1.000000  0.000000   0.0  0.000000   0.0
# doc5     0.000000   0.0  0.098216  0.000000  1.000000   0.0  0.000000   0.0
# ...           ...   ...       ...       ...       ...   ...       ...   ...
# doc5152  0.000000   0.0  0.000000  0.000000  0.000000   0.0  0.000000   0.0
# doc5153  0.000000   0.0  0.047243  0.000000  0.000000   0.0  0.000000   0.0
# doc5154  0.000000   0.0  0.000000  0.000000  0.000000   0.0  0.000000   0.0
# doc5155  0.000000   0.0  0.000000  0.000000  0.000000   0.0  0.000000   0.0
# doc5156  0.000000   0.0  0.025908  0.000000  0.000000   0.0  0.000000   0.0
#
#              doc9  doc10  ...  doc5147  doc5148  doc5149   doc5150   doc5151  \
# doc1     0.000000    0.0  ...      0.0      0.0      0.0  0.000000  0.000000
# doc2     0.321785    0.0  ...      0.0      0.0      0.0  0.000000  0.000000
# doc3     0.000000    0.0  ...      0.0      0.0      0.0  0.000000  0.019394
# doc4     0.000000    0.0  ...      0.0      0.0      0.0  0.000000  0.150818
# doc5     0.000000    0.0  ...      0.0      0.0      0.0  0.000000  0.000000
# ...           ...    ...  ...      ...      ...      ...       ...       ...
# doc5152  0.000000    0.0  ...      0.0      0.0      0.0  0.000000  0.000000
# doc5153  0.000000    0.0  ...      0.0      0.0      0.0  0.000000  0.040074
# doc5154  0.000000    0.0  ...      0.0      0.0      0.0  0.000000  0.000000
# doc5155  0.000000    0.0  ...      0.0      0.0      0.0  0.000000  0.000000
# doc5156  0.000000    0.0  ...      0.0      0.0      0.0  0.121596  0.000000
#
#          doc5152   doc5153  doc5154  doc5155   doc5156
# doc1         0.0  0.000000      0.0      0.0  0.000000
# doc2         0.0  0.000000      0.0      0.0  0.000000
# doc3         0.0  0.047243      0.0      0.0  0.025908
# doc4         0.0  0.000000      0.0      0.0  0.000000
# doc5         0.0  0.000000      0.0      0.0  0.000000
# ...          ...       ...      ...      ...       ...
# doc5152      1.0  0.000000      0.0      0.0  0.000000
# doc5153      0.0  1.000000      0.0      0.0  0.000000
# doc5154      0.0  0.000000      1.0      0.0  0.000000
# doc5155      0.0  0.000000      0.0      1.0  0.000000
# doc5156      0.0  0.000000      0.0      0.0  1.000000
#
# [5156 rows x 5156 columns]
